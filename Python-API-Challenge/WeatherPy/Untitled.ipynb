# %%
import pandas as pd

# %%
city_list_html = pd.read_csv('City_List.csv')
city_list_html
# Out:
#      Unnamed: 0              City    Lat     Lng  Max Temp(F)  Humidity(%)  \
# 0             0  andorra la vella  42.50    1.49        37.00           74
# 1             1       agarakadzor  39.73   45.35        42.80           70
# 2             2              berd  40.88   45.39        53.94           61
# 3             3       lanjaghbyur  40.27   45.14        44.60           81
# 4             4         shahumyan  39.94   44.57        44.60           81
# ..          ...               ...    ...     ...          ...          ...
# 611         611            tam ky  15.57  108.48        84.20           83
# 612         612          ekangala -25.70   28.75        69.01           82
# 613         613        phalaborwa -23.94   31.14        69.80           73
# 614         614        willowmore -33.29   23.49        58.06           63
# 615         615          siavonga -16.54   28.71        74.79           45
#
#      Cloudiness(%)  Wind Speed(MPH) Country        Date
# ...

# %%
del city_list_html['Unnamed: 0']

# %%
city_list_html
# Out:
#                  City    Lat     Lng  Max Temp(F)  Humidity(%)  Cloudiness(%)  \
# 0    andorra la vella  42.50    1.49        37.00           74              0
# 1         agarakadzor  39.73   45.35        42.80           70              0
# 2                berd  40.88   45.39        53.94           61              0
# 3         lanjaghbyur  40.27   45.14        44.60           81              0
# 4           shahumyan  39.94   44.57        44.60           81              0
# ..                ...    ...     ...          ...          ...            ...
# 611            tam ky  15.57  108.48        84.20           83             75
# 612          ekangala -25.70   28.75        69.01           82              0
# 613        phalaborwa -23.94   31.14        69.80           73              0
# 614        willowmore -33.29   23.49        58.06           63             61
# 615          siavonga -16.54   28.71        74.79           45              0
#
# ...

# %%
city_list_html.to_html('Data')
